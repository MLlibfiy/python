# %%
import seaborn as sns
import pandas as pd

df = pd.DataFrame({"x": [1, 2, 3, 4, 5, 6, 7], "y": [1, 2, 3, 4, 5, 6, 7]})
print(df)

sns.set(style="white")
sns.jointplot(x="x",y="y",data=df)
# Out:
#    x  y
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4
# 4  5  5
# 5  6  6
# 6  7  7
# C:\Users\Teacher\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Teacher\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
data = pd.read_csv("data/loandata.csv")
sns.jointplot(x="total_pymnt",y="total_rec_int",data=data,kind="reg")
# Out:
# C:\Users\Teacher\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Teacher\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="total_pymnt",y="total_rec_int",data=data,kind="hex")
# Out:
# C:\Users\Teacher\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Teacher\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="total_pymnt",y="total_rec_int",data=data,space=0,color="b",kind="kde")

# %%
sns.boxplot(x=data["loan_amnt"],color="r")

# %%
sns.boxplot(x="home_ownership",y="loan_amnt",data=data,color="r")

# %%
sns.boxplot(x="home_ownership",y="loan_amnt",data=data,color="r",hue="grade")

# %%
import numpy as np 
arr1 = np.random.normal(size=1000)

sns.distplot(arr1)
# Out:
# C:\Users\Teacher\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(arr1,rug=True,hist=False)

# %%
sns.distplot(arr1,rug=True,hist=False,vertical=True)

# %%
sns.countplot(x="grade",data=data)

# %%
sns.countplot(x="grade",data=data,hue="home_ownership")

# %%
sns.countplot(y="grade",data=data,hue="home_ownership")

# %%
sns.kdeplot(data["total_rec_int"])

# %%
sns.kdeplot(data["total_rec_int"],shade=True,color="g")

# %%
sns.kdeplot(data["total_rec_int"],data["total_pymnt"])

# %%
sns.violinplot(arr1)

# %%
sns.violinplot(x="home_ownership",y="loan_amnt",data=data)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,kind="reg")

# %%
sns.lmplot(x="total_pymnt",y="total_rec_int",data=data)

# %%
sns.lmplot(x="total_pymnt",y="total_rec_int",hue="home_ownership",data=data)

# %%
sns.lmplot(x="total_pymnt",y="total_rec_int",col="home_ownership",data=data)

# %%
sns.lmplot(x="total_pymnt",y="total_rec_int",col="home_ownership",row="grade",data=data)
